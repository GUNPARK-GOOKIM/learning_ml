# %% [markdown]
# Day - 1
# Learning the Pandas and cleaning the data

# %%
import pandas as pd

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("juhibhojani/house-price")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Lenovo\.cache\kagglehub\datasets\juhibhojani\house-price\versions\1

# %%
s = pd.read_csv('C:\\Users\\Lenovo\\learning_ml\\Phase_1\\house_prices.csv')

# %%
s.describe()
# Out:
#                Index  Price (in rupees)  Dimensions  Plot Area
# count  187531.000000       1.698660e+05         0.0        0.0
# mean    93765.000000       7.583772e+03         NaN        NaN
# std     54135.681003       2.724171e+04         NaN        NaN
# min         0.000000       0.000000e+00         NaN        NaN
# 25%     46882.500000       4.297000e+03         NaN        NaN
# 50%     93765.000000       6.034000e+03         NaN        NaN
# 75%    140647.500000       9.450000e+03         NaN        NaN
# max    187530.000000       6.700000e+06         NaN        NaN

# %%
s.head()
# Out:
#    Index                                              Title  \
# 0      0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1      1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2      2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3      3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4      4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
#
#                                          Description Amount(in rupees)  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...           42 Lac
# 1  One can find this stunning 2 BHK flat for sale...           98 Lac
# 2  Up for immediate sale is a 2 BHK apartment in ...          1.40 Cr
# 3  This beautiful 1 BHK Flat is available for sal...           25 Lac
# 4  This lovely 2 BHK Flat in Pokhran Road, Thane ...          1.60 Cr
#
#    Price (in rupees) location Carpet Area         Status         Floor  \
# 0             6000.0    thane    500 sqft  Ready to Move  10 out of 11
# ...

# %%
s.isnull().sum()
# Out:
# Index                     0
# Title                     0
# Description            3023
# Amount(in rupees)         0
# Price (in rupees)     17665
# location                  0
# Carpet Area           80673
# Status                  615
# Floor                  7077
# Transaction              83
# Furnishing             2897
# facing                70233
# overlooking           81436
# Society              109678
# Bathroom                828
# Balcony               48935
# Car Parking          103357
# Ownership             65517
# Super Area           107685
# Dimensions           187531
# Plot Area            187531
# dtype: int64

# %%
s.drop(columns = ['facing','Carpet Area','Car Parking','Super Area','Society','overlooking','Dimensions','Plot Area'], inplace = True)

# %%
s.head()
# Out:
#    Index                                              Title  \
# 0      0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1      1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2      2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3      3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4      4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
#
#                                          Description Amount(in rupees)  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...           42 Lac
# 1  One can find this stunning 2 BHK flat for sale...           98 Lac
# 2  Up for immediate sale is a 2 BHK apartment in ...          1.40 Cr
# 3  This beautiful 1 BHK Flat is available for sal...           25 Lac
# 4  This lovely 2 BHK Flat in Pokhran Road, Thane ...          1.60 Cr
#
#    Price (in rupees) location         Status         Floor Transaction  \
# 0        6000.000000    thane  Ready to Move  10 out of 11      Resale
# ...

# %%
s.fillna({"Furnishing":s["Furnishing"].mode()[0]}, inplace = True)
s.fillna({"Balcony": 0}, inplace=True)
s["Bathroom"] = pd.to_numeric(s["Bathroom"], errors="coerce")
s["Bathroom"] = s["Bathroom"].fillna(s["Bathroom"].median())
s.fillna({"Status":"Unknown"}, inplace = True)
s.fillna({"Ownership":"Unknown"}, inplace = True)
s.fillna({"Transaction":s["Transaction"].mode()[0]}, inplace = True)
s.fillna({"Price (in rupees)":s["Price (in rupees)"].mean()}, inplace = True)
s.fillna({"Floor":"Unknown"}, inplace = True)
s.fillna({"Description":"Unknown"},inplace = True)

# %%
s.isnull().sum()
# Out:
# Index                0
# Title                0
# Description          0
# Amount(in rupees)    0
# Price (in rupees)    0
# location             0
# Status               0
# Floor                0
# Transaction          0
# Furnishing           0
# Bathroom             0
# Balcony              0
# Ownership            0
# dtype: int64

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Index              187531 non-null  int64
#  1   Title              187531 non-null  object
#  2   Description        187531 non-null  object
#  3   Amount(in rupees)  187531 non-null  object
#  4   Price (in rupees)  187531 non-null  float64
#  5   location           187531 non-null  object
#  6   Status             187531 non-null  object
#  7   Floor              187531 non-null  object
#  8   Transaction        187531 non-null  object
#  9   Furnishing         187531 non-null  object
#  10  Bathroom           187531 non-null  float64
#  11  Balcony            187531 non-null  object
#  12  Ownership          187531 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 18.6+ MB

# %% [markdown]
# Day - 2
# Changing the datatypes and training the decision tree uisng sklearn

# %%
s = s.drop(columns=['Index'])

s['Title'] = s['Title'].astype('string')
s['Description'] = s['Description'].astype('string')

s['Amount(in rupees)'] = s['Amount(in rupees)'].str.replace(',', '', regex=False)
s['Amount(in rupees)'] = pd.to_numeric(s['Amount(in rupees)'], errors='coerce')

s['Price (in rupees)'] = s['Price (in rupees)'].astype('float32')
s['Bathroom'] = s['Bathroom'].astype('int8')

s['location'] = s['location'].astype('category')
s['Status'] = s['Status'].astype('category')
s['Transaction'] = s['Transaction'].astype('category')
s['Furnishing'] = s['Furnishing'].astype('category')
s['Ownership'] = s['Ownership'].astype('category')

s['Floor'] = s['Floor'].astype('category')

s['Balcony'] = pd.to_numeric(s['Balcony'], errors='coerce').fillna(0).astype('int8')

s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Title              187531 non-null  string
#  1   Description        187531 non-null  string
#  2   Amount(in rupees)  0 non-null       float64
#  3   Price (in rupees)  187531 non-null  float32
#  4   location           187531 non-null  category
#  5   Status             187531 non-null  category
#  6   Floor              187531 non-null  category
#  7   Transaction        187531 non-null  category
#  8   Furnishing         187531 non-null  category
#  9   Bathroom           187531 non-null  int8
#  10  Balcony            187531 non-null  int8
#  11  Ownership          187531 non-null  category
# dtypes: category(6), float32(1), float64(1), int8(2), string(2)
# memory usage: 6.7 MB

# %% [markdown]
# Dropping two more columns cause they do not affect the decision much

# %%
s = s.drop(columns=['Title', 'Description'])

# %%
s = pd.get_dummies(s, drop_first=True)

# %%
y = s['Price (in rupees)']
X = s.drop(columns = ['Price (in rupees)'])

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

model = DecisionTreeRegressor(
    max_depth=10,
    min_samples_split=10,
    min_samples_leaf=5,
    random_state=1
)

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=10, min_samples_leaf=5, min_samples_split=10,
#                       random_state=1)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

print("R2 Score:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: -0.2610018315650613
# MAE: 2074.3681383248163
# MSE: 574253122.2137115
# RMSE: 23963.579077711063
